# %%
# Leer el archivo excel
df = [    ['AFMUE1', 'Escritorio', 'Escritorio', 1, 1, 1000],
    ['AFMUE2', 'Silla de oficina', 'Silla de oficina', 2, 2, 500],
    ['AFMUE3', 'Armario archivador', 'Armario archivador', 3, 3, 1000],
    ['AFMUE4', 'Estantería', 'Estantería', 4, 4, 2000],
    ['AFMUE5', 'Credenza', 'Credenza', 5, 5, 100],
    ['AFMUE6', 'Mesa de conferencias', 'Mesa de conferencias', 6, 6, 4000],
    ['AFMUE7', 'Pizarra blanca', 'Pizarra blanca', 7, 7, 200],
    ['AFMUE8', 'Lámpara de escritorio', 'Lámpara de escritorio', 8, 8, 100],
    ['AFMUE9', 'Estación de trabajo', 'Estación de trabajo', 9, 9, 500],
    ['AFMUE10', 'Divisor de espacio', 'Divisor de espacio', 10, 10, 500]
]

# Iterar sobre cada fila e imprimir los valores de cada columna
for row in df:
    codigoaf = str(row[0])
    codigoaf1 = ''
    codigoaf2 = ''
    idsucursal = 0
    nombreaf = str(row[1])
    descaf = str(row[1])
    itemcode = str(row[3])
    loteserie = str(row[3])
    codgrupo = 'MUE-ESC'
    tipoaf = 'MUE'
    afesp = 'N'
    nomesq = ''
    foto = ''
    vcompra = str(row[5])
    frecep = '2022-10-01 00:00:00'
    prov = ''
    fabrica = ''
    codfabr = ''
    codbarr = ''
    estadoaf = 'Inactivo'
    bloqdes = frecep
    bloqhas = frecep
    ubicacion = 'SC-ADM'
    codresp = '2'
    resp = 'Adriana,Guaman'
    prjcode = ''
    consumo = '0'
    escomp = '0'
    valprop1 = ''
    valprop2 = ''
    valprop3 = ''
    valprop4 = ''
    valprop5 = ''
    valprop6 = ''
    valprop7 = ''
    valprop8 = ''
    valprop9 = ''
    valprop10 = ''
    aux1 = ''
    comment = ''
    estsys = '1'
    usrcrea = '40'
    fechacrea = "2022-10-01 00:00:0" + str(row[3])
    vidautil_cn = '0'
    unidvida_cn = '1'
    vidautil_sn = '0'
    unidvida_sn = '1'
    nomesq_sn = 'MUEBLES Y ENSERES'
    maskest = 'Inactivo'
    codafm = ''
    fecreg = ''
    idafdm = str(row[3])

    sql = "insert into \"AF_GANASEGUROS_QA\".\"DTMSTR\" values('" + codigoaf + "', '" + codigoaf1 + "', '" + codigoaf2 + "', " + str(idsucursal) + ", '" + nombreaf + "', '" + descaf + "', '" + itemcode + "', '" + loteserie + "', '" + codgrupo + "', '" + tipoaf + "', '" + afesp + "', '" + nomesq + "', '" + foto + "', '" + vcompra + "', '" + frecep + "', '" + prov + "', '" + fabrica + "', '" + codfabr + "', '" + codbarr + "', '" + estadoaf + "', '" + bloqdes + "', '" + bloqhas + "', '" + ubicacion + "', '" + codresp + "', '" + resp + "', '" + prjcode + "', '" + consumo + "', '" + escomp + "', '" + valprop1 + "', '" + valprop2 + "', '" + valprop3 + "', '" + valprop4 + "', '" + valprop5 + "', '" + valprop6 + "', '" + valprop7 + "', '" + valprop8 + "', '" + valprop9 + "', '" + valprop10 + "', '" + aux1 + "', '" + comment + "', '" + estsys + "', " + usrcrea + ", '" + fechacrea + "', '" + vidautil_cn + "', '" + unidvida_cn + "', '" + vidautil_sn + "', '" + unidvida_sn + "', '" + nomesq_sn + "', '" + maskest + "', '" + codafm + "', '" + fecreg + "', '" + idafdm + "');"

    print(sql)
# Out:
# insert into "AF_GANASEGUROS_QA"."DTMSTR" values('AFMUE1', '', '', 0, 'Escritorio', 'Escritorio', '1', '1', 'MUE-ESC', 'MUE', 'N', '', '', '1000', '2022-10-01 00:00:00', '', '', '', '', 'Inactivo', '2022-10-01 00:00:00', '2022-10-01 00:00:00', 'SC-ADM', '2', 'Adriana,Guaman', '', '0', '0', '', '', '', '', '', '', '', '', '', '', '', '', '1', 40, '2022-10-01 00:00:01', '0', '1', '0', '1', 'MUEBLES Y ENSERES', 'Inactivo', '', '', '1');
# insert into "AF_GANASEGUROS_QA"."DTMSTR" values('AFMUE2', '', '', 0, 'Silla de oficina', 'Silla de oficina', '2', '2', 'MUE-ESC', 'MUE', 'N', '', '', '500', '2022-10-01 00:00:00', '', '', '', '', 'Inactivo', '2022-10-01 00:00:00', '2022-10-01 00:00:00', 'SC-ADM', '2', 'Adriana,Guaman', '', '0', '0', '', '', '', '', '', '', '', '', '', '', '', '', '1', 40, '2022-10-01 00:00:02', '0', '1', '0', '1', 'MUEBLES Y ENSERES', 'Inactivo', '', '', '2');
# ...
